# %% [raw]
# ---
# sidebar_label: IsaacusByteStore
# ---

# %% [markdown]
# # IsaacusByteStore
#
# - TODO: Make sure API reference link is correct.
#
# This will help you get started with Isaacus [key-value stores](/docs/concepts/#key-value-stores). For detailed documentation of all IsaacusByteStore features and configurations head to the [API reference](https://python.langchain.com/v0.2/api_reference/core/stores/langchain_core.stores.langchain_isaacusByteStore.html).
#
# - TODO: Add any other relevant links, like information about models, prices, context windows, etc. See https://python.langchain.com/docs/integrations/stores/in_memory/ for an example.
#
# ## Overview
#
# - TODO: (Optional) A short introduction to the underlying technology/API.
#
# ### Integration details
#
# - TODO: Fill in table features.
# - TODO: Remove JS support link if not relevant, otherwise ensure link is correct.
# - TODO: Make sure API reference links are correct.
#
# | Class | Package | Local | [JS support](https://js.langchain.com/docs/integrations/stores/_package_name_) | Package downloads | Package latest |
# | :--- | :--- | :---: | :---: |  :---: | :---: |
# | [IsaacusByteStore](https://api.python.langchain.com/en/latest/stores/langchain_isaacus.stores.IsaacusByteStore.html) | [langchain-isaacus](https://api.python.langchain.com/en/latest/isaacus_api_reference.html) | ✅/❌ | ✅/❌ | ![PyPI - Downloads](https://img.shields.io/pypi/dm/langchain-isaacus?style=flat-square&label=%20) | ![PyPI - Version](https://img.shields.io/pypi/v/langchain-isaacus?style=flat-square&label=%20) |
#
# ## Setup
#
# - TODO: Update with relevant info.
#
# To create a Isaacus byte store, you'll need to create a/an Isaacus account, get an API key, and install the `langchain-isaacus` integration package.
#
# ### Credentials
#
# - TODO: Update with relevant info, or omit if the service does not require any credentials.
#
# Head to (TODO: link) to sign up to Isaacus and generate an API key. Once you've done this set the ISAACUS_API_KEY environment variable:

# %%
import getpass
import os

if not os.getenv("ISAACUS_API_KEY"):
    os.environ["ISAACUS_API_KEY"] = getpass.getpass("Enter your Isaacus API key: ")

# %% [markdown]
# ### Installation
#
# The LangChain Isaacus integration lives in the `langchain-isaacus` package:

# %%
# %pip install -qU langchain-isaacus

# %% [markdown]
# ## Instantiation
#
# Now we can instantiate our byte store:
#
# - TODO: Update model instantiation with relevant params.

# %%
from langchain_isaacus import IsaacusByteStore

kv_store = IsaacusByteStore(
    # params...
)

# %% [markdown]
# ## Usage
#
# - TODO: Run cells so output can be seen.
#
# You can set data under keys like this using the `mset` method:

# %%
kv_store.mset(
    [
        ["key1", b"value1"],
        ["key2", b"value2"],
    ]
)

kv_store.mget(
    [
        "key1",
        "key2",
    ]
)

# %% [markdown]
# And you can delete data using the `mdelete` method:

# %%
kv_store.mdelete(
    [
        "key1",
        "key2",
    ]
)

kv_store.mget(
    [
        "key1",
        "key2",
    ]
)

# %% [markdown]
# ## TODO: Any functionality specific to this key-value store provider
#
# E.g. extra initialization. Delete if not relevant.

# %% [markdown]
# ## API reference
#
# For detailed documentation of all IsaacusByteStore features and configurations, head to the API reference: https://api.python.langchain.com/en/latest/stores/langchain_isaacus.stores.IsaacusByteStore.html
